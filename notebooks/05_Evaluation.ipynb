# %% [markdown]
# Tabela comparativa e análise de comparação de resultados

# %%
resultados = pd.DataFrame({
    "Modelo": [
        "Baseline classe majoritária",
        "Baseline média",
        "Modelo ML",
        "Bandit"
    ],
    
    "ROC-AUC": [
        0.5,
        roc_auc_score(y_test, y_prob_baseline),
        None,
        None
    ],
    
    "F1": [
        f1_score(
            y_test,
            y_pred_baseline,
            zero_division=0
        ),
        None,
        None,
        None
    ]
})


resultados
